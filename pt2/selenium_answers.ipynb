# %% [markdown]
# # Answers to lecture

# %%
import pandas as pd
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.by import By

import time
import math

# %% [markdown]
# ## Set up
#
# Get `webdriver`, the dates, max rows visible, etc., all set up here.

# %%
# initiate webdriver
driver = webdriver.Chrome()

# %%
# "get" the webpage
driver.get('https://publicrecords.alameda.courts.ca.gov/CalendarSearch/')

# %%
hearing_date_from = driver.find_element(By.ID, 'FeaturedContent_txtFromdt')
hearing_date_to   = driver.find_element(By.ID, 'FeaturedContent_txtTodt')

# %%
hearing_date_from.send_keys('12/06/2021')
hearing_date_to.send_keys('12/06/2021')

# %%
submit_button = driver.find_element(By.ID, 'FeaturedContent_btFind')
submit_button.click()
time.sleep(5)

# %%
displayed_rows_dropdown = Select(driver.find_element(By.NAME, 'ctl00$MainContent$gvResult$ctl13$ctl13'))
displayed_rows_dropdown.select_by_visible_text('50')

# %%
records_count_container = driver.find_element(By.ID, 'MainContent_lbCnt')
records_count = records_count_container.text.split()
records_count = records_count[len(records_count) - 1]
records_count = int(records_count)
records_count
# Out:
# 1395

# %%
pages_to_check = math.ceil(records_count/50)
pages_to_check
# Out:
# 28

# %% [markdown]
# ## Create an empty dataframe to store all the data

# %%
hearings = pd.DataFrame(
    columns=[
        'Serial No.',
        'Name',
        'Case #',
        'PFN',
        'CEN',
        'Dept#',
        'Hearing Date',
        'Hearing Time',
        'Hearing Type',
        'Case Type',
        'Defense Atty',
        'DA'
    ])

# %% [markdown]
# ## Loop through all the pages
#
# ### Below I wrote a function `scrape_table()` that I can call from the loop.

# %%
def scrape_table(table):
    page_data = []
    rows = table.find_all('tr')
    for i, row in enumerate(rows):
        # we can skip the first row because that's the header row
        if (i > 0) and (i <= 50):
            cells = row.find_all('td')
            page_data.append({
                'Serial No.' : cells[0].text.strip(),
                'Name' : cells[1].text.strip(), 
                'Case #' : cells[2].text.strip(), 
                'PFN' : cells[3].text.strip(), 
                'CEN' : cells[4].text.strip(), 
                'Dept#' : cells[5].text.strip(), 
                'Hearing Date' : cells[6].text.strip(), 
                'Hearing Time' : cells[7].text.strip(), 
                'Hearing Type' : cells[8].text.strip(), 
                'Case Type' : cells[9].text.strip(), 
                'Defense Atty' : cells[10].text.strip(), 
                'DA' : cells[11].text.strip()
            })
    return pd.DataFrame(page_data)

# %% [markdown]
# ## Run the actual loop

# %%
for n in tqdm(range(pages_to_check)):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    table = soup.find(id='MainContent_gvResult')
    
    # scrape the page and create a dataframe
    page_df = scrape_table(table)
    
    # append the page dataframe to the main `hearings` dataframe
    hearings = hearings.append(page_df).reset_index(drop=True)
    
    # click on the next button and pause for 5 seconds
    next_button = driver.find_element(By.LINK_TEXT, '>')
    next_button.click()
    time.sleep(5)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/9b/jnjvzdvx77z055tn96mc36980000gp/T/ipykernel_72743/1187781327.py in <module>
#      10
#      11     # click on the next button and pause for 5 seconds
# ---> 12     next_button = driver.find_element(By.LINK_TEXT, '>')
#      13     next_button.click()
#      14     time.sleep(5)
#
# ~/.pyenv/versions/3.8.5/envs/scraping-lecture-3.8.5/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~/.pyenv/versions/3.8.5/envs/scraping-lecture-3.8.5/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~/.pyenv/versions/3.8.5/envs/scraping-lecture-3.8.5/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":">"}
#   (Session info: chrome=96.0.4664.55)
# Stacktrace:
# 0   chromedriver                        0x000000010277f269 __gxx_personality_v0 + 582729
# 1   chromedriver                        0x000000010270ac33 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x00000001022c7e28 chromedriver + 171560
# 3   chromedriver                        0x00000001022fd3d2 chromedriver + 390098
# 4   chromedriver                        0x00000001022fd591 chromedriver + 390545
# 5   chromedriver                        0x000000010232f6b4 chromedriver + 595636
# 6   chromedriver                        0x000000010231a9fd chromedriver + 510461
# 7   chromedriver                        0x000000010232d462 chromedriver + 586850
# 8   chromedriver                        0x000000010231ac23 chromedriver + 511011
# 9   chromedriver                        0x00000001022f075e chromedriver + 337758
# 10  chromedriver                        0x00000001022f1a95 chromedriver + 342677
# 11  chromedriver                        0x000000010273b8ab __gxx_personality_v0 + 305803
# 12  chromedriver                        0x0000000102752863 __gxx_personality_v0 + 399939
# 13  chromedriver                        0x0000000102757c7f __gxx_personality_v0 + 421471
# 14  chromedriver                        0x0000000102753bba __gxx_personality_v0 + 404890
# 15  chromedriver                        0x000000010272fe51 __gxx_personality_v0 + 258097
# 16  chromedriver                        0x000000010276f158 __gxx_personality_v0 + 516920
# 17  chromedriver                        0x000000010276f2e1 __gxx_personality_v0 + 517313
# 18  chromedriver                        0x00000001027866f8 __gxx_personality_v0 + 612568
# 19  libsystem_pthread.dylib             0x00007fff203eb8fc _pthread_start + 224
# 20  libsystem_pthread.dylib             0x00007fff203e7443 thread_start + 15

# %% [markdown]
# ## View the resulting dataframe

# %%
hearings
# Out:
#                                             Serial No.  \
# 0                                                    1
# 1                                                    2
# 2                                                    3
# 3                                                    4
# 4                                                    5
# ...                                                ...
# 1354                                              1393
# 1355                                              1394
# 1356                                              1395
# 1357  <<First<...19202122232425262728Rows:\n10\n20\n50
# 1358                                           <<First
#
#                           Name         Case #     PFN      CEN Dept#  \
# 0           FOSTER, JIMMIE LEE         167627  AYO984  1340030
# 1               THOMAS, MARKEL         410407  BGN192  8324445
# 2                 MOORE, MARIA  18-CR-019696B  BMD439  8418630   002
# 3              SALVANT, MARVEL  18-CR-019696A  BMD440  8418631   002
# 4     STANDLEY, CURTIS RICHARD   17-CR-027648  BGT167  7831868   003
# ...                        ...            ...     ...      ...   ...
# 1354      SMILEY, JASMON DANTE   21-CR-003317  DTF918  1368625   713
# 1355      SMILEY, JASMON DANTE   21-CR-003317  BDC095  1368625   713
# 1356      WELLS, DAVID MICHAEL   21-CR-012227  ASE868  1388635   713
# 1357                   <<First              <     ...       19    20
# 1358                         <            ...      19       20    21
#
#      Hearing Date Hearing Time         Hearing Type                Case Type  \
# 0      12/06/2021       9:00AM              Hearing                   Felony
# 1      12/06/2021       9:00AM              Hearing  Misdemeanor/Infractions
# 2      12/06/2021       8:30AM   Further Jury Trial                   Felony
# 3      12/06/2021       8:30AM   Further Jury Trial                   Felony
# 4      12/06/2021       8:30AM   Further Jury Trial                   Felony
# ...           ...          ...                  ...                      ...
# 1354   12/06/2021       8:30AM  Preliminary Hearing                   Felony
# 1355   12/06/2021       8:30AM  Preliminary Hearing                   Felony
# 1356   12/06/2021       8:30AM  Preliminary Hearing                   Felony
# 1357           21           22                   23                       24
# 1358           22           23                   24                       25
#
#                    Defense Atty                       DA
# 0
# 1
# 2     Darryl Antonio Stallworth      Alexander Hernandez
# 3         Christina Marie Moore      Alexander Hernandez
# 4          Anne Catherine Beles       Angelina Lisa Clay
# ...                         ...                      ...
# 1354  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1355  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1356  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1357                         25                       26
# 1358                         26                       27
#
# [1359 rows x 12 columns]

# %% [markdown]
# ## Clean up data

# %%
hearings['Hearing Type'].unique()
# Out:
# array(['Hearing', 'Further Jury Trial',
#        'Hearing After Revocation of Probation', 'Bail Hearing',
#        'Bail Bond Motion', 'Motion pursuant to 995PC', '8', '9',
#        'Sentence After Revocation', 'Report and Sentence',
#        'Set Hearing After Revocation of Probation',
#        'Parole Revocation Hearing',
#        'Post Release Community Supervision Hearing', 'Pretrial Hearing',
#        'Motion to Dismiss', 'Arraignment', 'Jury Trial',
#        'Readiness Hearing', 'For Review',
#        'District Attorney Petition to Revoke Probation', 'Plea Hearing',
#        'Disposition Hearing', 'Recall Bench Warrant',
#        'Drug Court Status Hearing', 'Diversion Hearing',
#        'Hearing on Petitions under Prop 47',
#        'Progress Report Early Intervention Court',
#        'Attorney and Plea Hearing', 'Progress Report',
#        'Execution of Sentence', 'Issue Bench Warrant',
#        '977 - Misdemeanor Disposition', 'Preliminary Hearing', 'Set',
#        'Summary Judgment Hearing', 'Resentencing/modification hearing',
#        'Set For Trial', 'Proof of Payment',
#        'Probation Department Petition to Revoke Probation',
#        'Preliminary Hearing and Motion to Suppress', '23', '24'],
#       dtype=object)

# %%
to_clean = ['8', '9', '23', '24']
hearings[hearings['Hearing Type'].isin(to_clean)]
# Out:
#                                             Serial No.     Name Case #  PFN  \
# 10              12345678910...>Last>>Rows:\n10\n20\n50        1      2    3
# 11                                                   1        2      3    4
# 1357  <<First<...19202122232425262728Rows:\n10\n20\n50  <<First      <  ...
# 1358                                           <<First        <    ...   19
#
#      CEN Dept# Hearing Date Hearing Time Hearing Type Case Type Defense Atty  \
# 10     4     5            6            7            8         9           10
# 11     5     6            7            8            9        10          ...
# 1357  19    20           21           22           23        24           25
# 1358  20    21           22           23           24        25           26
#
#        DA
# 10    ...
# 11      >
# 1357   26
# 1358   27

# %%
hearings = hearings[~hearings['Hearing Type'].isin(to_clean)].reset_index(drop=True)

# %%
hearings.tail()
# Out:
#      Serial No.                  Name        Case #     PFN      CEN Dept#  \
# 1350       1391         PRIETO, STEVE  21-CR-009297  BMZ282  1377159   713
# 1351       1392      RUIZ, TRINA LYNN  21-CR-011772  AYV628  1387766   713
# 1352       1393  SMILEY, JASMON DANTE  21-CR-003317  DTF918  1368625   713
# 1353       1394  SMILEY, JASMON DANTE  21-CR-003317  BDC095  1368625   713
# 1354       1395  WELLS, DAVID MICHAEL  21-CR-012227  ASE868  1388635   713
#
#      Hearing Date Hearing Time                                Hearing Type  \
# 1350   12/06/2021       8:30AM  Preliminary Hearing and Motion to Suppress
# 1351   12/06/2021       8:30AM                         Preliminary Hearing
# 1352   12/06/2021       8:30AM                         Preliminary Hearing
# 1353   12/06/2021       8:30AM                         Preliminary Hearing
# 1354   12/06/2021       8:30AM                         Preliminary Hearing
#
#      Case Type               Defense Atty                       DA
# 1350    Felony               Laura R Bull  Brooke Danielle Perkins
# 1351    Felony          Robbi Abrams Cook  Brooke Danielle Perkins
# 1352    Felony  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1353    Felony  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1354    Felony  Alexandria Grayson Blythe  Brooke Danielle Perkins

# %%
hearings['Serial No.'] = pd.to_numeric(hearings['Serial No.'])
hearings['Dept#'] = pd.to_numeric(hearings['Dept#'])

# %%
hearings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1355 entries, 0 to 1354
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Serial No.    1355 non-null   int64
#  1   Name          1355 non-null   object
#  2   Case #        1355 non-null   object
#  3   PFN           1355 non-null   object
#  4   CEN           1355 non-null   object
#  5   Dept#         1353 non-null   float64
#  6   Hearing Date  1355 non-null   object
#  7   Hearing Time  1355 non-null   object
#  8   Hearing Type  1355 non-null   object
#  9   Case Type     1355 non-null   object
#  10  Defense Atty  1355 non-null   object
#  11  DA            1355 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 127.2+ KB

# %%
hearings
# Out:
#       Serial No.                      Name         Case #     PFN      CEN  \
# 0              1        FOSTER, JIMMIE LEE         167627  AYO984  1340030
# 1              2            THOMAS, MARKEL         410407  BGN192  8324445
# 2              3              MOORE, MARIA  18-CR-019696B  BMD439  8418630
# 3              4           SALVANT, MARVEL  18-CR-019696A  BMD440  8418631
# 4              5  STANDLEY, CURTIS RICHARD   17-CR-027648  BGT167  7831868
# ...          ...                       ...            ...     ...      ...
# 1350        1391             PRIETO, STEVE   21-CR-009297  BMZ282  1377159
# 1351        1392          RUIZ, TRINA LYNN   21-CR-011772  AYV628  1387766
# 1352        1393      SMILEY, JASMON DANTE   21-CR-003317  DTF918  1368625
# 1353        1394      SMILEY, JASMON DANTE   21-CR-003317  BDC095  1368625
# 1354        1395      WELLS, DAVID MICHAEL   21-CR-012227  ASE868  1388635
#
#       Dept# Hearing Date Hearing Time  \
# 0       NaN   12/06/2021       9:00AM
# 1       NaN   12/06/2021       9:00AM
# 2       2.0   12/06/2021       8:30AM
# 3       2.0   12/06/2021       8:30AM
# 4       3.0   12/06/2021       8:30AM
# ...     ...          ...          ...
# 1350  713.0   12/06/2021       8:30AM
# 1351  713.0   12/06/2021       8:30AM
# 1352  713.0   12/06/2021       8:30AM
# 1353  713.0   12/06/2021       8:30AM
# 1354  713.0   12/06/2021       8:30AM
#
#                                     Hearing Type                Case Type  \
# 0                                        Hearing                   Felony
# 1                                        Hearing  Misdemeanor/Infractions
# 2                             Further Jury Trial                   Felony
# 3                             Further Jury Trial                   Felony
# 4                             Further Jury Trial                   Felony
# ...                                          ...                      ...
# 1350  Preliminary Hearing and Motion to Suppress                   Felony
# 1351                         Preliminary Hearing                   Felony
# 1352                         Preliminary Hearing                   Felony
# 1353                         Preliminary Hearing                   Felony
# 1354                         Preliminary Hearing                   Felony
#
#                    Defense Atty                       DA
# 0
# 1
# 2     Darryl Antonio Stallworth      Alexander Hernandez
# 3         Christina Marie Moore      Alexander Hernandez
# 4          Anne Catherine Beles       Angelina Lisa Clay
# ...                         ...                      ...
# 1350               Laura R Bull  Brooke Danielle Perkins
# 1351          Robbi Abrams Cook  Brooke Danielle Perkins
# 1352  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1353  Alexandria Grayson Blythe  Brooke Danielle Perkins
# 1354  Alexandria Grayson Blythe  Brooke Danielle Perkins
#
# [1355 rows x 12 columns]

# %% [markdown]
# ## Export the dataframe

# %%
hearings.to_csv('hearings.csv', index=False)

# %% [markdown]
# ## Explore the dataframe

# %%
hearing_types = hearings['Hearing Type'].unique()

# %%
hearing_types.sort()
hearing_types

# %%
hearings[hearings['Hearing Type'] == 'Drug Court Status Hearing']

# %%
Possible story idea: Drug courts?

https://www.dhcs.ca.gov/individuals/Pages/Drug-Courts-Overview.aspx

# %% [markdown]
# ## Close the automated browser

# %%
driver.close()
